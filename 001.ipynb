# %%
import pandas as pd
import numpy as np

mnist=pd.read_csv("../DataSet/mnist_test.csv")
y=mnist['label'].copy()
X=mnist.iloc[:,1:].copy()
X_m=np.zeros((10000,28,28))
for i in X.index:
    X_m[i]=np.array(X.iloc[i]).reshape(28,28)

# %% [markdown]
# # 此处是显示图片函数

# %%
import matplotlib.pyplot as plt
def show_picture(x,name,label):
    fig = plt.figure()
    plt.imshow(x,plt.cm.gray)
    plt.title(label)
    plt.savefig(name+".png")
# show_picture(X_m[1],"1",y[1])

# %%
# for i in range(10000):
#     show_picture(X_m[i],"pic/{}".format(i),y[i])
